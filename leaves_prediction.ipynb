# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('C:\\Users\\binary\\Downloads\\data_set.csv',encoding = 'latin')

# %%
#exploratory data analysis

print(df.shape)
df.head()
# Out:
# (40027, 20)
#    APPLICANT_ID LEAVE_TYPE STAFF_NO       DESIGNATION     LOCATION  \
# 0        102897         PL      159  Accounts Officer  Abbbottabad
# 1        105771         PL      159  Accounts Officer  Abbbottabad
# 2        102974         PL      221  Accounts Officer  Abbbottabad
# 3        102978         PL      221  Accounts Officer  Abbbottabad
# 4        102982         SL      221  Accounts Officer  Abbbottabad
#
#   HEAD_OF_DEPARTMENT    BUSINESS    DEPARTMENT SUPERVISOR     S_DATE  S_Month  \
# 0             Others  Business 5        Others     Others   4-Dec-15       12
# 1             Others  Business 5        Others     Others  17-Dec-16       12
# 2             Others  Business 5  Cirin Pharma     Others  29-Sep-16        9
# 3             Others  Business 5  Cirin Pharma     Others  30-Sep-16        9
# 4             Others  Business 5  Cirin Pharma     Others  14-Oct-16       10
#
#        E_DATE  SEASON  TOTAL_NO_DAYS  IS_ACTIVE   REASON  LEAVE_STATUS_ID  \
# 0   12/5/2015       1              1        1.0        1                8
# 1  12/17/2016       1              0        1.0     test                3
# 2   9/30/2016       4              1        1.0     test                8
# 3   10/1/2016       4              1        1.0  test 02                3
# 4  10/18/2016       4              4        1.0     test                8
#
#   BUSINESS_MANAGER  LEAVE_CODE      STATUS
# 0       Syed Akram        9001  Inprogress
# 1      Shabbir Ali        9004      Posted
# 2      Shabbir Ali        9001      Posted
# 3      Shabbir Ali        9004      Posted
# 4     Umran Shahid        9001      Posted

# %%
#filtering out data that is approved to predict the number of leaves that will be approved

df = df[df['STATUS']=='Posted']
print(df.shape)
df.head()
# Out:
# (26828, 20)
#    APPLICANT_ID LEAVE_TYPE STAFF_NO       DESIGNATION     LOCATION  \
# 1        105771         PL      159  Accounts Officer  Abbbottabad
# 2        102974         PL      221  Accounts Officer  Abbbottabad
# 3        102978         PL      221  Accounts Officer  Abbbottabad
# 4        102982         SL      221  Accounts Officer  Abbbottabad
# 5        103000         SL      221  Accounts Officer  Abbbottabad
#
#   HEAD_OF_DEPARTMENT    BUSINESS    DEPARTMENT SUPERVISOR     S_DATE  S_Month  \
# 1             Others  Business 5        Others     Others  17-Dec-16       12
# 2             Others  Business 5  Cirin Pharma     Others  29-Sep-16        9
# 3             Others  Business 5  Cirin Pharma     Others  30-Sep-16        9
# 4             Others  Business 5  Cirin Pharma     Others  14-Oct-16       10
# 5             Others  Business 5  Cirin Pharma     Others  29-Sep-16        9
#
#        E_DATE  SEASON  TOTAL_NO_DAYS  IS_ACTIVE   REASON  LEAVE_STATUS_ID  \
# 1  12/17/2016       1              0        1.0     test                3
# 2   9/30/2016       4              1        1.0     test                8
# 3   10/1/2016       4              1        1.0  test 02                3
# 4  10/18/2016       4              4        1.0     test                8
# 5   10/6/2016       4              7        1.0  testing                8
#
#   BUSINESS_MANAGER  LEAVE_CODE  STATUS
# 1      Shabbir Ali        9004  Posted
# 2      Shabbir Ali        9001  Posted
# 3      Shabbir Ali        9004  Posted
# 4     Umran Shahid        9001  Posted
# 5       Syed Akram        9001  Posted

# %%
df.keys()
# Out:
# Index(['APPLICANT_ID', 'LEAVE_TYPE', 'STAFF_NO', 'DESIGNATION', 'LOCATION',
#        'HEAD_OF_DEPARTMENT', 'BUSINESS', 'DEPARTMENT', 'SUPERVISOR', 'S_DATE',
#        'S_Month', 'E_DATE', 'SEASON', 'TOTAL_NO_DAYS', 'IS_ACTIVE', 'REASON',
#        'LEAVE_STATUS_ID', 'BUSINESS_MANAGER', 'LEAVE_CODE', 'STATUS'],
#       dtype='object')

# %%
df.dtypes
# Out:
# APPLICANT_ID            int64
# LEAVE_TYPE             object
# STAFF_NO               object
# DESIGNATION            object
# LOCATION               object
# HEAD_OF_DEPARTMENT     object
# BUSINESS               object
# DEPARTMENT             object
# SUPERVISOR             object
# S_DATE                 object
# S_Month                 int64
# E_DATE                 object
# SEASON                  int64
# TOTAL_NO_DAYS           int64
# IS_ACTIVE             float64
# REASON                 object
# LEAVE_STATUS_ID         int64
# BUSINESS_MANAGER       object
# LEAVE_CODE              int64
# STATUS                 object
# dtype: object

# %%
# feature elimination: discarding the irrelevant fields that won't have an effect on the number of leaves availed and on the overall predictions. 
df = df.drop(['APPLICANT_ID','IS_ACTIVE','REASON','STATUS'], axis = 1)

# %%
#spliting the data on training and testing
# data recorded in the year 2018 is used for testing and the model will be trained on the data before that

test = df[pd.to_datetime(df['S_DATE']).dt.year == 2018]
train = df[pd.to_datetime(df['S_DATE']).dt.year != 2018]

# %%
df['LEAVE_TYPE'].value_counts()
# Out:
# PL     17770
# SL      5567
# LW      1620
# EPL     1127
# LR       341
# PAL      221
# OL       120
# MAL       29
# TL        28
# PTL        5
# Name: LEAVE_TYPE, dtype: int64

# %%
df['LEAVE_CODE'].value_counts()
# Out:
# 9001    26555
# 9004     8047
# 9010     2218
# 9012     1631
# 1111      509
# 9011      475
# 9013      318
# 9019      180
# 9003       52
# 9005       35
# 9002        7
# Name: LEAVE_CODE, dtype: int64

# %%
# sdate and edate was helpful just for spliting data and won't contribute to the overall predictions so eliminating them as well 

train = train.drop(['S_DATE','E_DATE'], axis = 1)
test = test.drop(['S_DATE','E_DATE'], axis = 1)

# %%
print(train.shape)
print(test.shape)
# Out:
# (26381, 14)
# (447, 14)

# %%
df.keys()
# Out:
# Index(['LEAVE_TYPE', 'STAFF_NO', 'DESIGNATION', 'LOCATION',
#        'HEAD_OF_DEPARTMENT', 'BUSINESS', 'DEPARTMENT', 'SUPERVISOR', 'S_DATE',
#        'S_Month', 'E_DATE', 'SEASON', 'TOTAL_NO_DAYS', 'LEAVE_STATUS_ID',
#        'BUSINESS_MANAGER', 'LEAVE_CODE'],
#       dtype='object')

# %%
#assigning the features and targets variable. 

X_train = train.drop(['TOTAL_NO_DAYS'],axis = 1)
Y_train = train['TOTAL_NO_DAYS']

X_test = test.drop(['TOTAL_NO_DAYS'],axis = 1)
Y_test = test['TOTAL_NO_DAYS']

# %%
# combining the train and test features to label encode. there are a lot of new features that are present in 
# the testing data but not the training data like a new depatment added later in the years or any new employee joining.
# to avoid label encoder throwing an error we combine the data and fit that
data = X_train.append(X_test)

# %%
data.shape
# Out:
# (26828, 13)

# %%
#label encoder is used to encode features in a format that can  be understood by the model
# we fit the label encoder on the entire dataset and later on use it to transform our training and test sets

le = LabelEncoder()
for i in range(0,12):
    data.iloc[:,i] = le.fit_transform(data.iloc[:,i])
    X_test.iloc[:,i] = le.transform(X_test.iloc[:,i])
    X_train.iloc[:,i] = le.transform(X_train.iloc[:,i])

# %%
# since the spread of the data is a bit skewed and does not follow any fixed pregression non linear models like
# tree based algorithms can woek best. random forest being the most popular choice we go for this 
# keeping the samples split to 20 to bring about a generalizaton and avoid overfiting 
model = RandomForestRegressor(min_samples_split = 20,n_jobs = -1)

# %%
model.fit(X_train.values,Y_train.values)
# Out:
# c:\python36\scripts\osamaenv\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=20,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
# model predicting test values
pred = model.predict(X_test)

# %%
#changing format to integer
pred = pred.astype(int)

# %%
#error on a single prediciton
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Y_test,pred)
# Out:
# 2.335570469798658

# %%
#appending predictions to test data
test['pred'] = pred

# %%
test
# Out:
#       LEAVE_TYPE STAFF_NO                    DESIGNATION   LOCATION  \
# 127           PL     2197               Accounts Officer        KHI
# 167           PL     3706               Accounts Officer        KHI
# 360           PL      567               Accounts Officer        KHI
# 1044          SL     2172               Accounts Officer        KHI
# 1257         EPL     2488               Accounts Officer        KHI
# 1288          SL     2645               Accounts Officer        KHI
# 1346          PL     2890               Accounts Officer        KHI
# 1347          PL     2890               Accounts Officer        KHI
# 1348         EPL     2890               Accounts Officer        KHI
# 1370          PL     3496               Accounts Officer        KHI
# 1371          PL     3496               Accounts Officer        KHI
# 1372          PL     3496               Accounts Officer        KHI
# 1373          PL     3496               Accounts Officer        KHI
# 1374          PL     3496               Accounts Officer        KHI
# 1375          PL     3706               Accounts Officer        KHI
# 1377          PL     3885               Accounts Officer        LHR
# 1430          PL     1998         Administration Manager     Quetta
# 1431          PL     1998         Administration Manager     Quetta
# 1763          PL      516         Administration Manager        ISL
# 1764          PL      516         Administration Manager        ISL
# 2037          PL     2968            Area Manager Retail     Multan
# 2038          PL     2916  Analyst Business Intelligence        KHI
# 2095          PL      740                   Area Manager        KHI
# 2630          PL     2245                   Area Manager        KHI
# 2631          PL     2245                   Area Manager        KHI
# 2632          PL     2245                   Area Manager        KHI
# 2651          SL     2299                   Area Manager  Hyderabad
# 2749          PL     2572                   Area Manager  Hyderabad
# 2799          PL     2790                   Area Manager  Hyderabad
# 2860          SL     3249                   Area Manager  Islamabad
# ...          ...      ...                            ...        ...
# 37336         PL     3209     Technical Services Manager        KHI
# 37519         PL     3742              Territory Manager     Gujrat
# 38692                9    Shahana Murshad        9001     1
# 38737                3    Shahana Murshad        9001     1
# 38738                9       Umran Shahid        9001     2
# 38739                9       Umran Shahid        9001     1
# 38926                8    Shahana Murshad        9001     3
# 38927                8       Sidra Saleem        9010     3
# 39060                9       Sidra Saleem        9012     3
# 39061                9       Sidra Saleem        9012     3
# 39073                8    Shahana Murshad        9001     3
# 39074                8        Sana Idrees        9001     3
# 39204                9       Sidra Saleem        9001     4
# 39205                9    Shahana Murshad        9001     4
# 39644                3       Umran Shahid        9012     8
# 39656                3    Shahana Murshad        9001     4
# 39717                8    Mubashra Bukhsh        9001     3
# 39895                8    Shahana Murshad        9010     2
# 39971                3    Shahana Murshad        9001     4
#
# [447 rows x 15 columns]

# %%
print(test['S_Month'].value_counts())
print(test['BUSINESS'].value_counts())
# Out:
# 1    310
# 2    135
# 3      2
# Name: S_Month, dtype: int64
# Business 1    137
# Business 6    108
# Business 2     69
# Business 3     65
# Business 5     47
# Business 7     13
# Business 4      8
# Name: BUSINESS, dtype: int64

# %%
month_breakdown = test.groupby('S_Month')[['TOTAL_NO_DAYS','pred']].sum()

# %%
# agregating by monthly predicitons 
month_breakdown['accuracy'] = 100*(month_breakdown['TOTAL_NO_DAYS'] - abs(month_breakdown['TOTAL_NO_DAYS']- month_breakdown['pred']))/month_breakdown['TOTAL_NO_DAYS']

# %%
month_breakdown
# Out:
#          TOTAL_NO_DAYS  pred   accuracy
# S_Month
# 1                  732   803  90.300546
# 2                  381   372  97.637795
# 3                   21     7  33.333333

# %%
# agregating business wise leaves prediciton
business_breakdown = test.groupby('BUSINESS')[['TOTAL_NO_DAYS','pred']].sum()
business_breakdown['accuracy'] = 100*(business_breakdown['TOTAL_NO_DAYS'] - abs(business_breakdown['TOTAL_NO_DAYS']- business_breakdown['pred']))/business_breakdown['TOTAL_NO_DAYS']

# %%
business_breakdown
# Out:
#             TOTAL_NO_DAYS  pred   accuracy
# BUSINESS
# Business 1            315   282  89.523810
# Business 2            206   205  99.514563
# Business 3            179   214  80.446927
# Business 4             77    18  23.376623
# Business 5             99   139  59.595960
# Business 6            234   283  79.059829
# Business 7             24    41  29.166667

# %%
# aggregatiing predictions department wise 
department_breakdown = test.groupby('DEPARTMENT')[['TOTAL_NO_DAYS','pred']].sum()
department_breakdown['accuracy'] = 100*(department_breakdown['TOTAL_NO_DAYS'] - abs(department_breakdown['TOTAL_NO_DAYS']- department_breakdown['pred']))/department_breakdown['TOTAL_NO_DAYS']

# %%
department_breakdown
# Out:
#                                             TOTAL_NO_DAYS  pred    accuracy
# DEPARTMENT
# Administration                                         15     9   60.000000
# Agriculture                                            56    47   83.928571
# Animal Health                                          74    66   89.189189
# Business 3                                              2     6 -100.000000
# Chemical                                                1     2    0.000000
# Chemical & Agri                                         4     5   75.000000
# Cirin Pharma                                           50    58   84.000000
# Commercial                                             10    23  -30.000000
# Engineering Electrical And Instrumentation            105    79   75.238095
# Finance                                                24    25   95.833333
# Head Office                                             2    12 -400.000000
# Health & Safety                                        19     3   15.789474
# Human Resource                                         21    11   52.380952
# Information Technology                                 27    27  100.000000
# Marketing                                             102    60   58.823529
# Medical                                                23     4   17.391304
# Operations                                              1     8 -600.000000
# Others                                                146   158   91.780822
# Peads & Nutra                                           9     3   33.333333
# Pharmaceutical                                         26    23   88.461538
# Power Generation                                        3     3  100.000000
# Production                                            171   200   83.040936
# Raw Material                                            1     1  100.000000
# Reporting Group                                         3     3  100.000000
# SSD                                                     1     1  100.000000
# Salary                                                  2     8 -200.000000
# Sales                                                   0    11        -inf
# Shared Services Accounting                             13    27   -7.692308
# Shared Services Finance                                 6    29 -283.333333
# Shipping                                                3     6    0.000000
# Supply Chain                                           64    52   81.250000
# Technical                                             129   160   75.968992
# Technical & Enginearing                                10     8   80.000000
# Wyeth Pakistan                                         11    44 -200.000000

# %%
# aggregatiing predictions by leave types 

lt_breakdown = test.groupby('LEAVE_TYPE')[['TOTAL_NO_DAYS','pred']].sum()
lt_breakdown['accuracy'] = 100*(lt_breakdown['TOTAL_NO_DAYS'] - abs(lt_breakdown['TOTAL_NO_DAYS']- lt_breakdown['pred']))/lt_breakdown['TOTAL_NO_DAYS']
lt_breakdown
# Out:
#             TOTAL_NO_DAYS  pred   accuracy
# LEAVE_TYPE
# EPL                    30    32  93.333333
# LR                     19     9  47.368421
# LW                     35    42  80.000000
# PAL                    29    25  86.206897
# PL                    892   916  97.309417
# SL                    122   153  74.590164
# TL                      7     5  71.428571

# %%
# splitting all these breakdowns month wise

business = test.groupby(['S_Month','BUSINESS'])[['TOTAL_NO_DAYS','pred']].sum()

# %%
leave_type = test.groupby(['S_Month','LEAVE_TYPE'])[['TOTAL_NO_DAYS','pred']].sum()

# %%
dept = test.groupby(['S_Month','DEPARTMENT'])[['TOTAL_NO_DAYS','pred']].sum()

# %%
month = month_breakdown

# %%
business
# Out:
#                     TOTAL_NO_DAYS  pred
# S_Month BUSINESS
# 1       Business 1            258   214
#         Business 2             97   115
#         Business 3            107   151
#         Business 4             34     9
#         Business 5             70   100
#         Business 6            147   183
#         Business 7             19    31
# 2       Business 1             57    68
#         Business 2             88    83
#         Business 3             72    63
#         Business 4             43     9
#         Business 5             29    39
#         Business 6             87   100
#         Business 7              5    10
# 3       Business 2             21     7

# %%
month['difference'] = abs(month['TOTAL_NO_DAYS']-month['pred'])
month
# Out:
#          TOTAL_NO_DAYS  pred   accuracy  difference
# S_Month
# 1                  732   803  90.300546          71
# 2                  381   372  97.637795           9
# 3                   21     7  33.333333          14

# %%
dept['difference'] = abs(dept['TOTAL_NO_DAYS']-dept['pred'])
dept
# Out:
#                                                     TOTAL_NO_DAYS  pred  \
# S_Month DEPARTMENT
# 1       Administration                                          3     4
#         Agriculture                                            37    29
#         Animal Health                                          64    52
#         Business 3                                              2     6
#         Chemical & Agri                                         4     5
#         Cirin Pharma                                           32    31
#         Commercial                                              8    16
#         Engineering Electrical And Instrumentation             74    57
#         Finance                                                17    11
#         Head Office                                             1     6
#         Health & Safety                                        19     3
#         Human Resource                                          8     8
#         Information Technology                                  7    17
#         Marketing                                              11    25
#         Medical                                                23     4
#         Others                                                 94   124
#         Peads & Nutra                                           9     3
#         Pharmaceutical                                         12    13
#         Production                                            115   144
#         Raw Material                                            1     1
#         SSD                                                     1     1
#         Salary                                                  1     4
#         Sales                                                   0    11
#         Shared Services Accounting                             13    27
#         Shared Services Finance                                 3    18
#         Shipping                                                3     4
#         Supply Chain                                           53    37
#         Technical                                             102   108
#         Technical & Enginearing                                 9     5
#         Wyeth Pakistan                                          6    29
# 2       Administration                                         12     5
#         Agriculture                                            19    18
#         Animal Health                                          10    14
#         Chemical                                                1     2
#         Cirin Pharma                                           18    27
#         Commercial                                              2     7
#         Engineering Electrical And Instrumentation             31    22
#         Finance                                                 7    14
#         Head Office                                             1     6
#         Human Resource                                         13     3
#         Information Technology                                 20    10
#         Marketing                                              76    31
#         Operations                                              1     8
#         Others                                                 52    34
#         Pharmaceutical                                         14    10
#         Power Generation                                        3     3
#         Production                                             50    53
#         Reporting Group                                         3     3
#         Salary                                                  1     4
#         Shared Services Finance                                 3    11
#         Shipping                                                0     2
#         Supply Chain                                           11    15
#         Technical                                              27    52
#         Technical & Enginearing                                 1     3
#         Wyeth Pakistan                                          5    15
# 3       Marketing                                              15     4
#         Production                                              6     3
#
#                                                     difference
# S_Month DEPARTMENT
# 1       Administration                                       1
#         Agriculture                                          8
#         Animal Health                                       12
#         Business 3                                           4
#         Chemical & Agri                                      1
#         Cirin Pharma                                         1
#         Commercial                                           8
#         Engineering Electrical And Instrumentation          17
#         Finance                                              6
#         Head Office                                          5
#         Health & Safety                                     16
#         Human Resource                                       0
#         Information Technology                              10
#         Marketing                                           14
#         Medical                                             19
#         Others                                              30
#         Peads & Nutra                                        6
#         Pharmaceutical                                       1
#         Production                                          29
#         Raw Material                                         0
#         SSD                                                  0
#         Salary                                               3
#         Sales                                               11
#         Shared Services Accounting                          14
#         Shared Services Finance                             15
#         Shipping                                             1
#         Supply Chain                                        16
#         Technical                                            6
#         Technical & Enginearing                              4
#         Wyeth Pakistan                                      23
# 2       Administration                                       7
#         Agriculture                                          1
#         Animal Health                                        4
#         Chemical                                             1
#         Cirin Pharma                                         9
#         Commercial                                           5
#         Engineering Electrical And Instrumentation           9
#         Finance                                              7
#         Head Office                                          5
#         Human Resource                                      10
#         Information Technology                              10
#         Marketing                                           45
#         Operations                                           7
#         Others                                              18
#         Pharmaceutical                                       4
#         Power Generation                                     0
#         Production                                           3
#         Reporting Group                                      0
#         Salary                                               3
#         Shared Services Finance                              8
#         Shipping                                             2
#         Supply Chain                                         4
#         Technical                                           25
#         Technical & Enginearing                              2
#         Wyeth Pakistan                                      10
# 3       Marketing                                           11
#         Production                                           3

# %%
leave_type.to_csv('C:\\Users\\binary\\Downloads\\leave_type_leaves.csv')
